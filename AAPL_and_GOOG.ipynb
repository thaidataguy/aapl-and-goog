# %% [markdown]
# # The Symbiosis of Apple and Google
#
# Apple and Google are typically framed as rivals...

# %% [markdown]
# ## The Data
#
# Apple’s and Google’s Top Revenue Engines
#
# Link: https://docs.google.com/spreadsheets/d/1VAMyc90OjnCn-rbzLVYI_9r9B_CnLbTpbSHCDRThfWs/edit?usp=sharing

# %% [markdown]
# ## User Behavior and the Invisible Lock-In
#
# At the core of Apple and Google’s dominance is not just technology — it’s behavior...
#
# ### Apple’s Lock-In: Hardware + Emotional Gravity
#
# - Devices as anchors
# - Ecosystem gravity
# - Emotional loyalty
#
# ### Google’s Lock-In: Identity + Data Ubiquity
#
# - Identity as the gateway
# - Data exhaust as advantage
# - Ubiquity across devices

# %% [markdown]
# ## Preferable Buy-and-Hold Candidates
#
# The long-term case for holding both Apple (AAPL) and Alphabet (GOOG/L)...
#
# ### The Synthesis
#
# Holding both stocks is a strategic hedge...
